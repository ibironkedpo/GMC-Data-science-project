# %%
stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
print(stocks[0])
print(stocks[1])
print(stocks[6])
print(stocks[:3])
print(stocks[-1:])
print(stocks[-3:])
# Out:
# GOOG
# TSLA
# EUR/USD
# ['GOOG', 'TSLA', 'AAPL']
# ['EUR/USD']
# ['SP500', 'BTC', 'EUR/USD']

# %%
students = {name: "Dapo", school: "Futa", age: "30", gender: "male"}
print(students)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-de9b28e78163> in <cell line: 1>()
# ----> 1 students = {name: "Dapo", school: "Futa", age: "30", gender: "male"}
#       2 print(students)
#
# NameError: name 'name' is not defined
