# %%
import requests
import json
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://api.nasa.gov/planetary/apod?api_key=WhmqjVF0O6nSHjd6YWNX9WZZn7Sl75fqJTE1w7H3'
ds = requests.get(url).json()['url']
ds
# Out:
# 'https://www.youtube.com/embed/aX4ozspTPQY?rel=0'

# %%
from IPython.display import Image
Image(ds)
