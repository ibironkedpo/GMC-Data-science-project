# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"/content/train.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f40a54e5ce3f> in <cell line: 1>()
# ----> 1 data = pd.read_csv(r"/content/train.csv")
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588997 entries, 0 to 588996
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      588997 non-null  int64
#  1   vendor+AF8-id           588997 non-null  int64
#  2   pickup+AF8-loc          588997 non-null  int64
#  3   drop+AF8-loc            588997 non-null  int64
#  4   driver+AF8-tip          588996 non-null  object
#  5   mta+AF8-tax             588997 non-null  object
#  6   distance                588997 non-null  float64
#  7   pickup+AF8-time         588997 non-null  object
#  8   drop+AF8-time           588996 non-null  object
#  9   num+AF8-passengers      588996 non-null  float64
#  10  toll+AF8-amount         588995 non-null  float64
#  11  payment+AF8-method      588996 non-null  float64
#  12  rate+AF8-code           588996 non-null  float64
#  13  stored+AF8-flag         588996 non-null  object
# ...
