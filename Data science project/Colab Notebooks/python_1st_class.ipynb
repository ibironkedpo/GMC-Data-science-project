# %%
name = 'dapo'
number = 30
nameofstock = 'apple'

print (f"{name} owns {number} shares of {nameofstock}")
# Out:
# dapo owns 30 shares of apple

# %%
print(name + ' owns ' + str(number) + 'shares of' + nameofstock +'.' )
# Out:
# dapo owns 30shares ofapple.

# %%
name = input('what is my name? ')
# Out:
# what is my name? Dapo

# %%
favourite_meal = input('what is his favourite meal? ')
# Out:
# what is his favourite meal? Jollof Rice

# %%
print(f'{name} likes {favourite_meal}' )
# Out:
# Dapo likes Jollof Rice

# %%
number1 = input('provide the first number;')
number2 = input('provide the second number;')

number = number1 + number2
number

number = int(number1 + number2)
# Out:
# provide the first number;5
# provide the second number;6

# %%
price = int(input('Enter the price of the stock you want to buy;'))
number = int(input('Enter the number of stock you want to buy'))
name = input('Enter the name of the stock;')
Total = price*number
print(f'the total funds required to buy {number} {name} stock at {price} is {Total}')
# Out:
# Enter the price of the stock you want to buy;3000
# Enter the number of stock you want to buy5
# Enter the name of the stock;AMZN
# the total funds required to buy 5 AMZN stock at 3000 is 15000

# %%
price = int(input('Enter the price of the stock you want to buy;'))
number = int(input('Enter the number of stock you want to buy;'))
name = input('Enter the name of te stock;')
Total = price*number
print(f'The total funds required to buy {number} {name} stocks at {price} is {Total}')
# Out:
# Enter the price of the stock you want to buy;4000
# Enter the number of stock you want to buy;10
# Enter the name of te stock;google
# The total funds required to buy 10 google stocks at 4000 is 40000

# %% [markdown]
# Write a code that performs the following mathematical operation?

# %%
x = 5
y = 6

z = abs(x - y) * (x + y)
print(z)
# Out:
# 11
