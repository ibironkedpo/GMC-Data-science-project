# %%
import pandas as pd

# %%
clients_0_bills = pd.read_csv(r'/content/STEG_BILLING_HISTORY.csv')

# %%
clients_0_bills.head(10)
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0             0.0
# 1  train_Client_0   2013-03-29          11       1335667.0             0.0
# 2  train_Client_0   2015-03-23          11       1335667.0             0.0
# 3  train_Client_0   2015-07-13          11       1335667.0             0.0
# 4  train_Client_0   2016-11-17          11       1335667.0             0.0
# 5  train_Client_0   2017-07-17          11       1335667.0             0.0
# 6  train_Client_0   2018-12-07          11       1335667.0             0.0
# 7  train_Client_0   2019-03-19          11       1335667.0             0.0
# 8  train_Client_0   2011-07-22          11       1335667.0             0.0
# 9  train_Client_0   2011-11-22          11       1335667.0             0.0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
clients_0_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103071 entries, 0 to 103070
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             103071 non-null  object
#  1   invoice_date          103071 non-null  object
#  2   tarif_type            103071 non-null  int64
#  3   counter_number        103069 non-null  float64
#  4   counter_statue        103070 non-null  float64
#  5   counter_code          103070 non-null  float64
#  6   reading_remarque      102980 non-null  float64
#  7   counter_coefficient   103070 non-null  float64
#  8   consommation_level_1  103070 non-null  float64
#  9   consommation_level_2  103070 non-null  float64
#  10  consommation_level_3  103070 non-null  float64
#  11  consommation_level_4  103070 non-null  float64
#  12  old_index             103070 non-null  float64
#  13  new_index             103070 non-null  float64
# ...

# %%
#What is the data type of the 'client_0_bills' variable ?
clients_0_bills.dtypes
# Out:
# client_id                object
# invoice_date             object
# tarif_type                int64
# counter_number          float64
# counter_statue          float64
# counter_code            float64
# reading_remarque        float64
# counter_coefficient     float64
# consommation_level_1    float64
# consommation_level_2    float64
# consommation_level_3    float64
# consommation_level_4    float64
# old_index               float64
# new_index               float64
# months_number           float64
# counter_type             object
# dtype: object

# %%
#Inspect the dataset for potential missing values
clients_0_bills.isnull().sum()
# Out:
# client_id                0
# invoice_date             0
# tarif_type               0
# counter_number           2
# counter_statue           1
# counter_code             1
# reading_remarque        91
# counter_coefficient      1
# consommation_level_1     1
# consommation_level_2     1
# consommation_level_3     1
# consommation_level_4     1
# old_index                1
# new_index                1
# months_number            1
# counter_type             1
# dtype: int64

# %%
#Select your strategy to handle missing values, and tell us why you had made that choice.
clients_0_bills['invoice_date'].mode()[0]
# Out:
# '2010-04-10'

# %%
clients_0_bills['tarif_type'].mode()[0]
# Out:
# 11

# %%
clients_0_bills['counter_number'].mode()[0]
# Out:
# 0.0

# %%
clients_0_bills['counter_statue'].mode()[0]
# Out:
# 0.0

# %%
clients_0_bills['counter_code'].mode()[0]
# Out:
# 203.0

# %%
clients_0_bills['counter_coefficient'].mode()
